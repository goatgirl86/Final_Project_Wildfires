# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Resources/temps_to_7.csv")
df
# Out:
#        fire_index  fire_size      fire_cause   latitude   longitude state  \
# 0               3       1.00  Debris Burning  39.641400 -119.308300    NV
# 1              24      40.00           Arson  31.435181  -88.999489    MS
# 2              31       1.20  Debris Burning  48.833000  -99.783600    ND
# 3              35      30.18  Debris Burning  31.259000  -84.895600    GA
# 4              36    1420.00       Lightning  33.241800 -104.912200    NM
# ...           ...        ...             ...        ...         ...   ...
# 13133       55336    3409.00       Utilities  31.059000  -98.956367    TX
# 13134       55337    4582.00       Utilities  30.075167  -97.149167    TX
# 13135       55341   17823.00      Accidental  44.834600 -117.220600    OR
# 13136       55342    5086.00  Debris Burning  45.656100 -109.114200    MT
# 13137       55343    5963.00  Debris Burning  43.785671 -115.985922    ID
#
#       discovery_month  Temp_pre_30  Temp_pre_15  Temp_pre_7  Wind_pre_30  \
# ...

# %%
df30 = df[[ 'fire_index','Temp_pre_30', 'Wind_pre_30',
                'Hum_pre_30']]
df30.to_csv("Resources/df30k.csv")

# %%
df15 = df[[ 'fire_index','Temp_pre_15', 'Wind_pre_15',
                'Hum_pre_15']]
df15.to_csv("Resources/df15k.csv")

# %%
df7 = df[[ 'fire_index','Temp_pre_7', 'Wind_pre_7',
                'Hum_pre_7']]
df7.to_csv("Resources/df7k.csv")

# %%
fire_info_df = df[['fire_index', 'fire_size', 'fire_cause', 'latitude', 'longitude', 'state', 'discovery_month', 'putout_time','year']]
fire_info_df.to_csv("Resources/fire_info_dfk.csv")

# %%
fire_name --> 'fire_index', 'fire_name'
fire_info --> 'fire_index', 'fire_size', 'fire_cause', 'discovery_month', 'putout_time','year'
fire_location --> 'fire_index', 'latitude', 'longitude', 'state', 
weather_data --> 'fire_index','Temp_pre_30', 'Wind_pre_30', 'Hum_pre_30','Temp_pre_15', 'Wind_pre_15', 'Hum_pre_15', 
                'Temp_pre_7', 'Wind_pre_7', 'Hum_pre_7',
fire_city --> API--> "city", "fire_latitude", "fire_longitude"

# %%
import matplotlib.pyplot as plt
# Import the style from Matplotlib.
from matplotlib import style
# %matplotlib inline


# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')
fig,ax = plt.subplots()
df.plot(x='year', y='fire_size', kind='scatter', figsize = (20,6), ax=ax)
ax.set_title("fire size by year")
ax.set_xlabel("year")
ax.set_ylabel("fire_size")
#ax.legend(title = "type", loc = "center")
plt.tight_layout()
#the chart is saved to analysis folder
#plt.savefig("analysis/PyBer_fare_summary.png")

#show chart

plt.show()
