# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
data_to_load = "cleaned_disaster_data_1900-2021.csv"
data = pd.read_csv(data_to_load)

# %%
data['Prediction'] = 0

# %%
data
# Out:
#        Unnamed: 0  Year        Disaster Type Disaster Subgroup  \
# 0               5  1903  Mass movement (dry)       Geophysical
# 1               8  1905  Mass movement (dry)       Geophysical
# 2              33  1911             Wildfire    Climatological
# 3              35  1912                Storm    Meteorological
# 4              37  1914           Earthquake       Geophysical
# ...           ...   ...                  ...               ...
# 11612       16121  2021                Flood      Hydrological
# 11613       16122  2021                Flood      Hydrological
# 11614       16123  2021             Epidemic        Biological
# 11615       16124  2021                Flood      Hydrological
# 11616       16125  2021                Flood      Hydrological
#
#        Disaster Subtype                                 Country Continent  \
# 0              Rockfall                                  Canada  Americas
# ...

# %%
# Encoding with Pandas
binary_encoded = pd.get_dummies(data, columns=["Disaster Type","Disaster Subgroup",	"Disaster Subtype","Country","Continent"])
binary_encoded
# Out:
#        Unnamed: 0  Year  Total Deaths  Total Affected  Prediction  \
# 0               5  1903          76.0            23.0           0
# 1               8  1905          18.0            18.0           0
# 2              33  1911          73.0           200.0           0
# 3              35  1912          28.0          2700.0           0
# 4              37  1914          20.0            20.0           0
# ...           ...   ...           ...             ...         ...
# 11612       16121  2021          11.0         67980.0           0
# 11613       16122  2021          31.0           400.0           0
# 11614       16123  2021         131.0           301.0           0
# 11615       16124  2021           NaN            22.0           0
# 11616       16125  2021           7.0        500000.0           0
#
#        Disaster Type_Animal accident  Disaster Type_Drought  \
# 0                                  0                      0
# ...

# %%
### Encoding done through sklearn

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df2 = data.copy()
df2['Disaster Type'] = le.fit_transform(df2['Disaster Type'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df3 = df2.copy()
df3['Disaster Subgroup'] = le.fit_transform(df2['Disaster Subgroup'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df4 = df3.copy()
df4['Disaster Subtype'] = le.fit_transform(df2['Disaster Subtype'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df5 = df4.copy()
df5['Country'] = le.fit_transform(df2['Country'])

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
encoded_df = df5.copy()
encoded_df['Continent'] = le.fit_transform(df2['Continent'])

# %%
encoded_df
# Out:
#        Unnamed: 0  Year  Disaster Type  Disaster Subgroup  Disaster Subtype  \
# 0               5  1903             10                  3                19
# 1               8  1905             10                  3                19
# 2              33  1911             13                  1                 9
# 3              35  1912             11                  5                 5
# 4              37  1914              2                  3                10
# ...           ...   ...            ...                ...               ...
# 11612       16121  2021              5                  4                25
# 11613       16122  2021              5                  4                25
# 11614       16123  2021              3                  0                24
# 11615       16124  2021              5                  4                25
# 11616       16125  2021              5                  4                25
#
# ...
