# %%
import csv
import pandas as pd
import numpy as np

# %%
file_to_read = pd.read_csv(r"C:\Users\zirot\Classwork\Natural_Disasters\Resources\1900_2021_DISASTERS.xlsx - emdat data.csv")

# %%
df = pd.DataFrame(file_to_read)
df
# Out:
#        Year   Seq           Glide Disaster Group Disaster Subgroup  \
# 0      1900  9002             NaN        Natural    Climatological
# 1      1900  9001             NaN        Natural    Climatological
# 2      1902    12             NaN        Natural       Geophysical
# 3      1902     3             NaN        Natural       Geophysical
# 4      1902    10             NaN        Natural       Geophysical
# ...     ...   ...             ...            ...               ...
# 16121  2021   449  FL-2021-000110        Natural      Hydrological
# 16122  2021    75             NaN        Natural      Hydrological
# 16123  2021   599  EP-2021-000138        Natural        Biological
# 16124  2021    20             NaN        Natural      Hydrological
# 16125  2021   481             NaN        Natural      Hydrological
#
#            Disaster Type Disaster Subtype Disaster Subsubtype   Event Name  \
# 0                Drought          Drought                 NaN          NaN
# ...

# %%
new_df = df.filter(items=['Year', 'Disaster Type','Country','Disaster Group'])

# %%
new_df
# Out:
#        Year      Disaster Type                                 Country  \
# 0      1900            Drought                              Cabo Verde
# 1      1900            Drought                                   India
# 2      1902         Earthquake                               Guatemala
# 3      1902  Volcanic activity                               Guatemala
# 4      1902  Volcanic activity                               Guatemala
# ...     ...                ...                                     ...
# 16121  2021              Flood                                   Yemen
# 16122  2021              Flood                            South Africa
# 16123  2021           Epidemic  Congo (the Democratic Republic of the)
# 16124  2021              Flood                                  Serbia
# 16125  2021              Flood                             South Sudan
#
#       Disaster Group
# 0            Natural
# 1            Natural
# 2            Natural
# 3            Natural
# ...

# %%
twenty_21 = new_df[new_df["Year"] == 2021]

# %%
twenty_21
# Out:
#        Year Disaster Type                                 Country  \
# 15237  2021         Storm                                   Chile
# 15238  2021         Storm                    Czech Republic (the)
# 15239  2021         Storm                                  France
# 15240  2021         Storm                                   Spain
# 15241  2021         Storm                                   China
# ...     ...           ...                                     ...
# 16121  2021         Flood                                   Yemen
# 16122  2021         Flood                            South Africa
# 16123  2021      Epidemic  Congo (the Democratic Republic of the)
# 16124  2021         Flood                                  Serbia
# 16125  2021         Flood                             South Sudan
#
#       Disaster Group
# 15237        Natural
# 15238        Natural
# 15239        Natural
# 15240        Natural
# 15241        Natural
# ...              ...
# ...

# %%
#Adding to Make a test push
