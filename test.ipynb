# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Resources/cleaned_wildfire_7.csv")
df
# Out:
#        Unnamed: 0  fire_size      fire_cause   latitude   longitude state  \
# 0               3       1.00  Debris Burning  39.641400 -119.308300    NV
# 1              24      40.00           Arson  31.435181  -88.999489    MS
# 2              26       2.00  Debris Burning  35.718900  -92.335000    AR
# 3              31       1.20  Debris Burning  48.833000  -99.783600    ND
# 4              35      30.18  Debris Burning  31.259000  -84.895600    GA
# ...           ...        ...             ...        ...         ...   ...
# 15326       55336    3409.00       Utilities  31.059000  -98.956367    TX
# 15327       55337    4582.00       Utilities  30.075167  -97.149167    TX
# 15328       55341   17823.00      Accidental  44.834600 -117.220600    OR
# 15329       55342    5086.00  Debris Burning  45.656100 -109.114200    MT
# 15330       55343    5963.00  Debris Burning  43.785671 -115.985922    ID
#
#       discovery_month  Temp_pre_30  Temp_pre_15  Temp_pre_7  ...  Hum_pre_30  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'fire_size', 'fire_cause', 'latitude', 'longitude',
#        'state', 'discovery_month', 'Temp_pre_30', 'Temp_pre_15', 'Temp_pre_7',
#        'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7', 'Wind_cont',
#        'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont', 'Prec_pre_30',
#        'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'year', 'putout_time'],
#       dtype='object')

# %%
df=df.rename(columns={"Unnamed: 0": "fire_index"})
df
# Out:
#        fire_index  fire_size      fire_cause   latitude   longitude state  \
# 0               3       1.00  Debris Burning  39.641400 -119.308300    NV
# 1              24      40.00           Arson  31.435181  -88.999489    MS
# 2              26       2.00  Debris Burning  35.718900  -92.335000    AR
# 3              31       1.20  Debris Burning  48.833000  -99.783600    ND
# 4              35      30.18  Debris Burning  31.259000  -84.895600    GA
# ...           ...        ...             ...        ...         ...   ...
# 15326       55336    3409.00       Utilities  31.059000  -98.956367    TX
# 15327       55337    4582.00       Utilities  30.075167  -97.149167    TX
# 15328       55341   17823.00      Accidental  44.834600 -117.220600    OR
# 15329       55342    5086.00  Debris Burning  45.656100 -109.114200    MT
# 15330       55343    5963.00  Debris Burning  43.785671 -115.985922    ID
#
#       discovery_month  Temp_pre_30  Temp_pre_15  Temp_pre_7  ...  Hum_pre_30  \
# ...

# %%
df.columns
# Out:
# Index(['fire_index', 'fire_size', 'fire_cause', 'latitude', 'longitude',
#        'state', 'discovery_month', 'Temp_pre_30', 'Temp_pre_15', 'Temp_pre_7',
#        'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7', 'Wind_cont',
#        'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont', 'Prec_pre_30',
#        'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'year', 'putout_time'],
#       dtype='object')

# %%
df=df[['fire_index', 'fire_size', 'fire_cause', 'latitude', 'longitude',
       'state', 'discovery_month', 'Temp_pre_30', 'Temp_pre_15', 'Temp_pre_7',
       'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7', 'Wind_cont',
       'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont', 'Prec_pre_30',
       'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'year', 'putout_time']]
df
# Out:
#        fire_index  fire_size      fire_cause   latitude   longitude state  \
# 0               3       1.00  Debris Burning  39.641400 -119.308300    NV
# 1              24      40.00           Arson  31.435181  -88.999489    MS
# 2              26       2.00  Debris Burning  35.718900  -92.335000    AR
# 3              31       1.20  Debris Burning  48.833000  -99.783600    ND
# 4              35      30.18  Debris Burning  31.259000  -84.895600    GA
# ...           ...        ...             ...        ...         ...   ...
# 15326       55336    3409.00       Utilities  31.059000  -98.956367    TX
# 15327       55337    4582.00       Utilities  30.075167  -97.149167    TX
# 15328       55341   17823.00      Accidental  44.834600 -117.220600    OR
# 15329       55342    5086.00  Debris Burning  45.656100 -109.114200    MT
# 15330       55343    5963.00  Debris Burning  43.785671 -115.985922    ID
#
#       discovery_month  Temp_pre_30  Temp_pre_15  Temp_pre_7  ...  Hum_pre_30  \
# ...

# %%
df.to_csv("Resources/cleaned_wildfire_8.csv", index = False)

# %%
df = pd.read_csv("Resources/cleaned_wildfire_8.csv")
df
# Out:
#        fire_index  fire_size      fire_cause   latitude   longitude state  \
# 0               3       1.00  Debris Burning  39.641400 -119.308300    NV
# 1              24      40.00           Arson  31.435181  -88.999489    MS
# 2              26       2.00  Debris Burning  35.718900  -92.335000    AR
# 3              31       1.20  Debris Burning  48.833000  -99.783600    ND
# 4              35      30.18  Debris Burning  31.259000  -84.895600    GA
# ...           ...        ...             ...        ...         ...   ...
# 15326       55336    3409.00       Utilities  31.059000  -98.956367    TX
# 15327       55337    4582.00       Utilities  30.075167  -97.149167    TX
# 15328       55341   17823.00      Accidental  44.834600 -117.220600    OR
# 15329       55342    5086.00  Debris Burning  45.656100 -109.114200    MT
# 15330       55343    5963.00  Debris Burning  43.785671 -115.985922    ID
#
#       discovery_month  Temp_pre_30  Temp_pre_15  Temp_pre_7  ...  Hum_pre_30  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15331 entries, 0 to 15330
# Data columns (total 25 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fire_index       15331 non-null  int64
#  1   fire_size        15331 non-null  float64
#  2   fire_cause       15331 non-null  object
#  3   latitude         15331 non-null  float64
#  4   longitude        15331 non-null  float64
#  5   state            15331 non-null  object
#  6   discovery_month  15331 non-null  object
#  7   Temp_pre_30      15331 non-null  float64
#  8   Temp_pre_15      15331 non-null  float64
#  9   Temp_pre_7       15331 non-null  float64
#  10  Temp_cont        15331 non-null  float64
#  11  Wind_pre_30      15331 non-null  float64
#  12  Wind_pre_15      15331 non-null  float64
#  13  Wind_pre_7       15331 non-null  float64
#  14  Wind_cont        15331 non-null  float64
#  15  Hum_pre_30       15331 non-null  float64
# ...

# %%
df[['fire_size']].describe()
# Out:
#            fire_size
# count   15331.000000
# mean     4804.186598
# std     22930.445973
# min         0.510000
# 25%         1.800000
# 50%         6.000000
# 75%       125.500000
# max    538049.000000

# %%
df_10 = df.loc[(df["fire_size"] >= 10)]
df_10
# Out:
#        fire_index  fire_size      fire_cause   latitude   longitude state  \
# 1              24      40.00           Arson  31.435181  -88.999489    MS
# 4              35      30.18  Debris Burning  31.259000  -84.895600    GA
# 5              36    1420.00       Lightning  33.241800 -104.912200    NM
# 6              48      55.00  Debris Burning  37.464589  -81.491224    WV
# 8              56      15.30       Utilities  36.586500  -96.323220    OK
# ...           ...        ...             ...        ...         ...   ...
# 15326       55336    3409.00       Utilities  31.059000  -98.956367    TX
# 15327       55337    4582.00       Utilities  30.075167  -97.149167    TX
# 15328       55341   17823.00      Accidental  44.834600 -117.220600    OR
# 15329       55342    5086.00  Debris Burning  45.656100 -109.114200    MT
# 15330       55343    5963.00  Debris Burning  43.785671 -115.985922    ID
#
#       discovery_month  Temp_pre_30  Temp_pre_15  Temp_pre_7  ...  Hum_pre_30  \
# ...

# %%
df_10.dropna()
df_10
# Out:
#        Unnamed: 0.1  fire_size fire_size_class stat_cause_descr   latitude  \
# 36               36     1420.0               F        Lightning  33.241800
# 40               40        5.0               B        Lightning  40.834700
# 64               64        1.5               B        Lightning  39.205000
# 79               79        2.5               B        Lightning  42.364444
# 84               84      108.0               D        Lightning  63.851700
# ...             ...        ...             ...              ...        ...
# 55330         55330     9211.0               G        Lightning  44.237000
# 55331         55331     3082.0               F        Lightning  48.383600
# 55332         55332     5200.0               G        Lightning  30.865978
# 55356         55356     4336.0               F        Lightning  34.316000
# 55357         55357     4856.0               F        Lightning  29.616667
#
# ...

# %%
df_10.drop(columns="veg_label")
# Out:
#               fire_name  fire_size      fire_cause   latitude   longitude  \
# 35     FY2001-EARLY-021      30.18  Debris Burning  31.259000  -84.895600
# 36                LUCKY    1420.00       Lightning  33.241800 -104.912200
# 48        LAUREL BRANCH      55.00  Debris Burning  37.464589  -81.491224
# 56      LED BETTER BARN      15.30       Utilities  36.586500  -96.323220
# 57           CALDERWOOD     270.00           Arson  35.473333  -84.450000
# ...                 ...        ...             ...        ...         ...
# 55336         LOG CABIN    3409.00       Utilities  31.059000  -98.956367
# 55337      HIDDEN PINES    4582.00       Utilities  30.075167  -97.149167
# 55341         DRY GULCH   17823.00      Accidental  44.834600 -117.220600
# 55342         PINECREST    5086.00  Debris Burning  45.656100 -109.114200
# 55343            WALKER    5963.00  Debris Burning  43.785671 -115.985922
#
#       state discovery_month  year  putout_time  Temp_pre_30  ...  Wind_cont  \
# ...

# %%
Q1 = df['fire_size'].quantile(0.25)
Q1
# Out:
# 2.0

# %%
Q3 = df['fire_size'].quantile(0.75)
Q3
# Out:
# 3400.0

# %%
IQR = Q3-Q1
IQR
# Out:
# 3398.0

# %%
lower_lim = Q1-(1.5*IQR)
upper_lim = Q3+(1.5*IQR)

# %%
lower_lim
# Out:
# -5095.0

# %%
upper_lim
# Out:
# 8497.0

# %%
outliers_15_low = (df["fire_size"] < lower_lim)
outliers_15_up = (df["fire_size"] > upper_lim)

# %%
len(df['fire_size'])-(len(df['fire_size'][outliers_15_low]) +
                      len(df["fire_size"][outliers_15_up]))
# Out:
# 11927

# %%
df["fire_size"][(outliers_15_low | outliers_15_up)]
# Out:
# 734      10610.0
# 1855     19520.0
# 2317     13804.0
# 2449     67008.0
# 2569     33362.6
#           ...
# 55329    49100.0
# 55333    10468.0
# 55335     8500.0
# 55341    17823.0
# 55349    17831.0
# Name: fire_size, Length: 1825, dtype: float64

# %%
df["fire_size"][~(outliers_15_low | outliers_15_up)]
# Out:
# 3           1.00
# 9           1.00
# 26          2.00
# 31          1.20
# 35         30.18
#           ...
# 55337    4582.00
# 55342    5086.00
# 55343    5963.00
# 55350    3452.00
# 55351    8300.00
# Name: fire_size, Length: 11927, dtype: float64

# %%
df_no_out = df[~(outliers_15_low | outliers_15_up)]
df_no_out
# Out:
#               fire_name  fire_size      fire_cause   latitude   longitude  \
# 3                WNA  1       1.00  Debris Burning  39.641400 -119.308300
# 9                 CRAZY       1.00           Other  48.839400  -99.718500
# 26           STO3573155       2.00  Debris Burning  35.718900  -92.335000
# 31          AXE RONDEAU       1.20  Debris Burning  48.833000  -99.783600
# 35     FY2001-EARLY-021      30.18  Debris Burning  31.259000  -84.895600
# ...                 ...        ...             ...        ...         ...
# 55337      HIDDEN PINES    4582.00       Utilities  30.075167  -97.149167
# 55342         PINECREST    5086.00  Debris Burning  45.656100 -109.114200
# 55343            WALKER    5963.00  Debris Burning  43.785671 -115.985922
# 55350    PRICKLEY PEAR     3452.00           Other  30.400883 -101.331933
# 55351  COTTONWOOD GULCH    8300.00           Other  45.922100 -111.422500
#
#       state discovery_month  year  putout_time  Temp_pre_30  ...  Hum_pre_30  \
# ...

# %%
boxplot = df_no_out.boxplot(column=['fire_size'])

# %%
df_no_out.describe()
# Out:
#           fire_size      latitude     longitude          year   putout_time  \
# count  11927.000000  11927.000000  11927.000000  11927.000000  11927.000000
# mean     854.979987     38.492789   -101.763743   2006.329756      4.797854
# std     1934.753592      7.008239     16.125471      6.544947     15.972934
# min        0.510000     17.983333   -165.116700   1992.000000      0.000000
# 25%        1.500000     33.520017   -114.152400   2001.000000      0.000000
# 50%        5.000000     36.855400   -101.064600   2008.000000      0.000000
# 75%       80.000000     43.106400    -86.393900   2012.000000      2.000000
# max     8497.000000     68.819400    -67.066666   2015.000000    261.000000
#
#         Temp_pre_30   Temp_pre_15    Temp_pre_7     Temp_cont   Wind_pre_30  \
# count  11927.000000  11927.000000  11927.000000  11927.000000  11927.000000
# mean      15.135954     15.419580     15.644783      7.004118      2.969763
# ...
